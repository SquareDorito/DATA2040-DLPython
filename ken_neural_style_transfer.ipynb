# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.1.6'

# %%
from keras.preprocessing.image import load_img, img_to_array

# This is the path to the image you want to transform.
target_image_path = 'transfer_style_imgs/content1.jpg'
# This is the path to the style image.
style_reference_image_path = 'transfer_style_imgs/style1.jpg'

# Dimensions of the generated picture.
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
print(width)
print(height)
# Out:
# 525
# 350

# %%
import numpy as np
from keras.applications import vgg19

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

def deprocess_image(x):
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

# We build the VGG19 network with our batch of 3 images as input.
# The model will be loaded with pre-trained ImageNet weights.
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
# Out:
# Model loaded.

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram


def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_height * img_width
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def total_variation_loss(x):
    a = K.square(
        x[:, :img_height - 1, :img_width - 1, :] - x[:, 1:, :img_width - 1, :])
    b = K.square(
        x[:, :img_height - 1, :img_width - 1, :] - x[:, :img_height - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block5_conv2'
# Name of layers used for style loss
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import time

result_prefix = 'style_transfer_result'
iterations = 10

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=10)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 4.15645e+10
# Image saved as style_transfer_result_at_iteration_0.png
# Iteration 0 completed in 97s
# Start of iteration 1
# Current loss value: 1.13751e+10
# Image saved as style_transfer_result_at_iteration_1.png
# Iteration 1 completed in 96s
# Start of iteration 2
# Current loss value: 5.91815e+09
# Image saved as style_transfer_result_at_iteration_2.png
# Iteration 2 completed in 97s
# Start of iteration 3
# Current loss value: 4.26982e+09
# Image saved as style_transfer_result_at_iteration_3.png
# Iteration 3 completed in 96s
# Start of iteration 4
# Current loss value: 3.17406e+09
# Image saved as style_transfer_result_at_iteration_4.png
# Iteration 4 completed in 97s
# Start of iteration 5
# Current loss value: 2.36275e+09
# Image saved as style_transfer_result_at_iteration_5.png
# Iteration 5 completed in 96s
# Start of iteration 6
# Current loss value: 2.03108e+09
# Image saved as style_transfer_result_at_iteration_6.png
# Iteration 6 completed in 97s
# Start of iteration 7
# Current loss value: 1.72884e+09
# Image saved as style_transfer_result_at_iteration_7.png
# Iteration 7 completed in 97s
# Start of iteration 8
# Current loss value: 1.53127e+09
# Image saved as style_transfer_result_at_iteration_8.png
# Iteration 8 completed in 96s
# Start of iteration 9
# Current loss value: 1.40488e+09
# Image saved as style_transfer_result_at_iteration_9.png
# Iteration 9 completed in 96s

# %% [markdown]
# Here's what we get:

# %%
from matplotlib import pyplot as plt

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()

# %%
import keras
from keras.preprocessing.image import load_img, img_to_array

# This is the path to the image you want to transform.
target_image_path = 'transfer_style_imgs/content1.jpg'
# This is the path to the style image.
style_reference_image_path = 'transfer_style_imgs/style2.jpg'

# Dimensions of the generated picture.
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
print(width)
print(height)
# Out:
# 525
# 350

# %%
from keras.applications import vgg16

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg16.preprocess_input(img)
    return img

def deprocess_image(x):
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K
import numpy as np

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

# We build the VGG19 network with our batch of 3 images as input.
# The model will be loaded with pre-trained ImageNet weights.
model = vgg16.VGG16(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'block5_conv2'
# Name of layers used for style loss
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1',
                'block4_conv1',
                'block5_conv1']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-4
style_weight = 1.25
content_weight = 0.020

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import time

result_prefix = 'style_transfer_result_2'
iterations = 10

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 9.60966e+09
# Image saved as style_transfer_result_2_at_iteration_0.png
# Iteration 0 completed in 162s
# Start of iteration 1
# Current loss value: 2.2263e+09
# Image saved as style_transfer_result_2_at_iteration_1.png
# Iteration 1 completed in 162s
# Start of iteration 2
# Current loss value: 1.14273e+09
# Image saved as style_transfer_result_2_at_iteration_2.png
# Iteration 2 completed in 162s
# Start of iteration 3
# Current loss value: 7.40662e+08
# Image saved as style_transfer_result_2_at_iteration_3.png
# Iteration 3 completed in 162s
# Start of iteration 4
# Current loss value: 5.03726e+08
# Image saved as style_transfer_result_2_at_iteration_4.png
# Iteration 4 completed in 162s
# Start of iteration 5
# Current loss value: 3.94574e+08
# Image saved as style_transfer_result_2_at_iteration_5.png
# Iteration 5 completed in 162s
# Start of iteration 6
# Current loss value: 3.21263e+08
# Image saved as style_transfer_result_2_at_iteration_6.png
# Iteration 6 completed in 162s
# Start of iteration 7
# Current loss value: 2.70389e+08
# Image saved as style_transfer_result_2_at_iteration_7.png
# Iteration 7 completed in 162s
# Start of iteration 8
# Current loss value: 2.35265e+08
# Image saved as style_transfer_result_2_at_iteration_8.png
# Iteration 8 completed in 162s
# Start of iteration 9
# Current loss value: 2.07064e+08
# Image saved as style_transfer_result_2_at_iteration_9.png
# Iteration 9 completed in 162s

# %%
from matplotlib import pyplot as plt

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()

# %%
import keras

from keras.preprocessing.image import load_img, img_to_array

# This is the path to the image you want to transform.
target_image_path = 'transfer_style_imgs/content1.jpg'
# This is the path to the style image.
style_reference_image_path = 'transfer_style_imgs/style3.jpg'

# Dimensions of the generated picture.
width, height = load_img(target_image_path).size
img_height = 400
img_width = int(width * img_height / height)
print(width)
print(height)
# Out:
# 525
# 350

# %%
print(img_height)
print(img_width)
# Out:
# 400
# 600

# %%
import numpy as np
from keras.applications import inception_v3

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = inception_resnet_v2.preprocess_input(img)
    return img

def deprocess_image(x):
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
from keras import backend as K

target_image = K.constant(preprocess_image(target_image_path))
style_reference_image = K.constant(preprocess_image(style_reference_image_path))

# This placeholder will contain our generated image
combination_image = K.placeholder((1, img_height, img_width, 3))

# We combine the 3 images into a single batch
input_tensor = K.concatenate([target_image,
                              style_reference_image,
                              combination_image], axis=0)

# We build the VGG19 network with our batch of 3 images as input.
# The model will be loaded with pre-trained ImageNet weights.
model = inception_v3.InceptionV3(input_tensor=input_tensor,
                    weights='imagenet',
                    include_top=False,
                    pooling='max')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, None, None, 3 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, None, None, 3 96          conv2d_298[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, None, None, 3 0           batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, None, None, 3 9216        activation_298[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, None, None, 3 96          conv2d_299[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, None, None, 3 0           batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, None, None, 6 18432       activation_299[0][0]
# __________________________________________________________________________________________________
# batch_normalization_300 (BatchN (None, None, None, 6 192         conv2d_300[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, None, None, 6 0           batch_normalization_300[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 6 0           activation_300[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_301 (BatchN (None, None, None, 8 240         conv2d_301[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, None, None, 8 0           batch_normalization_301[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, None, None, 1 138240      activation_301[0][0]
# __________________________________________________________________________________________________
# batch_normalization_302 (BatchN (None, None, None, 1 576         conv2d_302[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, None, None, 1 0           batch_normalization_302[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, None, None, 1 0           activation_302[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_306 (BatchN (None, None, None, 6 192         conv2d_306[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, None, None, 6 0           batch_normalization_306[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, None, None, 9 55296       activation_306[0][0]
# __________________________________________________________________________________________________
# batch_normalization_304 (BatchN (None, None, None, 4 144         conv2d_304[0][0]
# __________________________________________________________________________________________________
# batch_normalization_307 (BatchN (None, None, None, 9 288         conv2d_307[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, None, None, 4 0           batch_normalization_304[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, None, None, 9 0           batch_normalization_307[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11 (AveragePo (None, None, None, 1 0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, None, None, 6 76800       activation_304[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, None, None, 9 82944       activation_307[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, None, None, 3 6144        average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_303 (BatchN (None, None, None, 6 192         conv2d_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_305 (BatchN (None, None, None, 6 192         conv2d_305[0][0]
# __________________________________________________________________________________________________
# batch_normalization_308 (BatchN (None, None, None, 9 288         conv2d_308[0][0]
# __________________________________________________________________________________________________
# batch_normalization_309 (BatchN (None, None, None, 3 96          conv2d_309[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, None, None, 6 0           batch_normalization_303[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, None, None, 6 0           batch_normalization_305[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, None, None, 9 0           batch_normalization_308[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, None, None, 3 0           batch_normalization_309[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_303[0][0]
#                                                                  activation_305[0][0]
#                                                                  activation_308[0][0]
#                                                                  activation_309[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_313 (BatchN (None, None, None, 6 192         conv2d_313[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, None, None, 6 0           batch_normalization_313[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, None, None, 9 55296       activation_313[0][0]
# __________________________________________________________________________________________________
# batch_normalization_311 (BatchN (None, None, None, 4 144         conv2d_311[0][0]
# __________________________________________________________________________________________________
# batch_normalization_314 (BatchN (None, None, None, 9 288         conv2d_314[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, None, None, 4 0           batch_normalization_311[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, None, None, 9 0           batch_normalization_314[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, None, None, 6 76800       activation_311[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, None, None, 9 82944       activation_314[0][0]
# __________________________________________________________________________________________________
# conv2d_316 (Conv2D)             (None, None, None, 6 16384       average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_310 (BatchN (None, None, None, 6 192         conv2d_310[0][0]
# __________________________________________________________________________________________________
# batch_normalization_312 (BatchN (None, None, None, 6 192         conv2d_312[0][0]
# __________________________________________________________________________________________________
# batch_normalization_315 (BatchN (None, None, None, 9 288         conv2d_315[0][0]
# __________________________________________________________________________________________________
# batch_normalization_316 (BatchN (None, None, None, 6 192         conv2d_316[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, None, None, 6 0           batch_normalization_310[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, None, None, 6 0           batch_normalization_312[0][0]
# __________________________________________________________________________________________________
# activation_315 (Activation)     (None, None, None, 9 0           batch_normalization_315[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, None, None, 6 0           batch_normalization_316[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_310[0][0]
#                                                                  activation_312[0][0]
#                                                                  activation_315[0][0]
#                                                                  activation_316[0][0]
# __________________________________________________________________________________________________
# conv2d_320 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_320 (BatchN (None, None, None, 6 192         conv2d_320[0][0]
# __________________________________________________________________________________________________
# activation_320 (Activation)     (None, None, None, 6 0           batch_normalization_320[0][0]
# __________________________________________________________________________________________________
# conv2d_318 (Conv2D)             (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_321 (Conv2D)             (None, None, None, 9 55296       activation_320[0][0]
# __________________________________________________________________________________________________
# batch_normalization_318 (BatchN (None, None, None, 4 144         conv2d_318[0][0]
# __________________________________________________________________________________________________
# batch_normalization_321 (BatchN (None, None, None, 9 288         conv2d_321[0][0]
# __________________________________________________________________________________________________
# activation_318 (Activation)     (None, None, None, 4 0           batch_normalization_318[0][0]
# __________________________________________________________________________________________________
# activation_321 (Activation)     (None, None, None, 9 0           batch_normalization_321[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_317 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_319 (Conv2D)             (None, None, None, 6 76800       activation_318[0][0]
# __________________________________________________________________________________________________
# conv2d_322 (Conv2D)             (None, None, None, 9 82944       activation_321[0][0]
# __________________________________________________________________________________________________
# conv2d_323 (Conv2D)             (None, None, None, 6 18432       average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_317 (BatchN (None, None, None, 6 192         conv2d_317[0][0]
# __________________________________________________________________________________________________
# batch_normalization_319 (BatchN (None, None, None, 6 192         conv2d_319[0][0]
# __________________________________________________________________________________________________
# batch_normalization_322 (BatchN (None, None, None, 9 288         conv2d_322[0][0]
# __________________________________________________________________________________________________
# batch_normalization_323 (BatchN (None, None, None, 6 192         conv2d_323[0][0]
# __________________________________________________________________________________________________
# activation_317 (Activation)     (None, None, None, 6 0           batch_normalization_317[0][0]
# __________________________________________________________________________________________________
# activation_319 (Activation)     (None, None, None, 6 0           batch_normalization_319[0][0]
# __________________________________________________________________________________________________
# activation_322 (Activation)     (None, None, None, 9 0           batch_normalization_322[0][0]
# __________________________________________________________________________________________________
# activation_323 (Activation)     (None, None, None, 6 0           batch_normalization_323[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_317[0][0]
#                                                                  activation_319[0][0]
#                                                                  activation_322[0][0]
#                                                                  activation_323[0][0]
# __________________________________________________________________________________________________
# conv2d_325 (Conv2D)             (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_325 (BatchN (None, None, None, 6 192         conv2d_325[0][0]
# __________________________________________________________________________________________________
# activation_325 (Activation)     (None, None, None, 6 0           batch_normalization_325[0][0]
# __________________________________________________________________________________________________
# conv2d_326 (Conv2D)             (None, None, None, 9 55296       activation_325[0][0]
# __________________________________________________________________________________________________
# batch_normalization_326 (BatchN (None, None, None, 9 288         conv2d_326[0][0]
# __________________________________________________________________________________________________
# activation_326 (Activation)     (None, None, None, 9 0           batch_normalization_326[0][0]
# __________________________________________________________________________________________________
# conv2d_324 (Conv2D)             (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_327 (Conv2D)             (None, None, None, 9 82944       activation_326[0][0]
# __________________________________________________________________________________________________
# batch_normalization_324 (BatchN (None, None, None, 3 1152        conv2d_324[0][0]
# __________________________________________________________________________________________________
# batch_normalization_327 (BatchN (None, None, None, 9 288         conv2d_327[0][0]
# __________________________________________________________________________________________________
# activation_324 (Activation)     (None, None, None, 3 0           batch_normalization_324[0][0]
# __________________________________________________________________________________________________
# activation_327 (Activation)     (None, None, None, 9 0           batch_normalization_327[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_324[0][0]
#                                                                  activation_327[0][0]
#                                                                  max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_332 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_332 (BatchN (None, None, None, 1 384         conv2d_332[0][0]
# __________________________________________________________________________________________________
# activation_332 (Activation)     (None, None, None, 1 0           batch_normalization_332[0][0]
# __________________________________________________________________________________________________
# conv2d_333 (Conv2D)             (None, None, None, 1 114688      activation_332[0][0]
# __________________________________________________________________________________________________
# batch_normalization_333 (BatchN (None, None, None, 1 384         conv2d_333[0][0]
# __________________________________________________________________________________________________
# activation_333 (Activation)     (None, None, None, 1 0           batch_normalization_333[0][0]
# __________________________________________________________________________________________________
# conv2d_329 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_334 (Conv2D)             (None, None, None, 1 114688      activation_333[0][0]
# __________________________________________________________________________________________________
# batch_normalization_329 (BatchN (None, None, None, 1 384         conv2d_329[0][0]
# __________________________________________________________________________________________________
# batch_normalization_334 (BatchN (None, None, None, 1 384         conv2d_334[0][0]
# __________________________________________________________________________________________________
# activation_329 (Activation)     (None, None, None, 1 0           batch_normalization_329[0][0]
# __________________________________________________________________________________________________
# activation_334 (Activation)     (None, None, None, 1 0           batch_normalization_334[0][0]
# __________________________________________________________________________________________________
# conv2d_330 (Conv2D)             (None, None, None, 1 114688      activation_329[0][0]
# __________________________________________________________________________________________________
# conv2d_335 (Conv2D)             (None, None, None, 1 114688      activation_334[0][0]
# __________________________________________________________________________________________________
# batch_normalization_330 (BatchN (None, None, None, 1 384         conv2d_330[0][0]
# __________________________________________________________________________________________________
# batch_normalization_335 (BatchN (None, None, None, 1 384         conv2d_335[0][0]
# __________________________________________________________________________________________________
# activation_330 (Activation)     (None, None, None, 1 0           batch_normalization_330[0][0]
# __________________________________________________________________________________________________
# activation_335 (Activation)     (None, None, None, 1 0           batch_normalization_335[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_328 (Conv2D)             (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_331 (Conv2D)             (None, None, None, 1 172032      activation_330[0][0]
# __________________________________________________________________________________________________
# conv2d_336 (Conv2D)             (None, None, None, 1 172032      activation_335[0][0]
# __________________________________________________________________________________________________
# conv2d_337 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_328 (BatchN (None, None, None, 1 576         conv2d_328[0][0]
# __________________________________________________________________________________________________
# batch_normalization_331 (BatchN (None, None, None, 1 576         conv2d_331[0][0]
# __________________________________________________________________________________________________
# batch_normalization_336 (BatchN (None, None, None, 1 576         conv2d_336[0][0]
# __________________________________________________________________________________________________
# batch_normalization_337 (BatchN (None, None, None, 1 576         conv2d_337[0][0]
# __________________________________________________________________________________________________
# activation_328 (Activation)     (None, None, None, 1 0           batch_normalization_328[0][0]
# __________________________________________________________________________________________________
# activation_331 (Activation)     (None, None, None, 1 0           batch_normalization_331[0][0]
# __________________________________________________________________________________________________
# activation_336 (Activation)     (None, None, None, 1 0           batch_normalization_336[0][0]
# __________________________________________________________________________________________________
# activation_337 (Activation)     (None, None, None, 1 0           batch_normalization_337[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_328[0][0]
#                                                                  activation_331[0][0]
#                                                                  activation_336[0][0]
#                                                                  activation_337[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_342 (BatchN (None, None, None, 1 480         conv2d_342[0][0]
# __________________________________________________________________________________________________
# activation_342 (Activation)     (None, None, None, 1 0           batch_normalization_342[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, None, None, 1 179200      activation_342[0][0]
# __________________________________________________________________________________________________
# batch_normalization_343 (BatchN (None, None, None, 1 480         conv2d_343[0][0]
# __________________________________________________________________________________________________
# activation_343 (Activation)     (None, None, None, 1 0           batch_normalization_343[0][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, None, None, 1 179200      activation_343[0][0]
# __________________________________________________________________________________________________
# batch_normalization_339 (BatchN (None, None, None, 1 480         conv2d_339[0][0]
# __________________________________________________________________________________________________
# batch_normalization_344 (BatchN (None, None, None, 1 480         conv2d_344[0][0]
# __________________________________________________________________________________________________
# activation_339 (Activation)     (None, None, None, 1 0           batch_normalization_339[0][0]
# __________________________________________________________________________________________________
# activation_344 (Activation)     (None, None, None, 1 0           batch_normalization_344[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, None, None, 1 179200      activation_339[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, None, None, 1 179200      activation_344[0][0]
# __________________________________________________________________________________________________
# batch_normalization_340 (BatchN (None, None, None, 1 480         conv2d_340[0][0]
# __________________________________________________________________________________________________
# batch_normalization_345 (BatchN (None, None, None, 1 480         conv2d_345[0][0]
# __________________________________________________________________________________________________
# activation_340 (Activation)     (None, None, None, 1 0           batch_normalization_340[0][0]
# __________________________________________________________________________________________________
# activation_345 (Activation)     (None, None, None, 1 0           batch_normalization_345[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, None, None, 1 215040      activation_340[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, None, None, 1 215040      activation_345[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_338 (BatchN (None, None, None, 1 576         conv2d_338[0][0]
# __________________________________________________________________________________________________
# batch_normalization_341 (BatchN (None, None, None, 1 576         conv2d_341[0][0]
# __________________________________________________________________________________________________
# batch_normalization_346 (BatchN (None, None, None, 1 576         conv2d_346[0][0]
# __________________________________________________________________________________________________
# batch_normalization_347 (BatchN (None, None, None, 1 576         conv2d_347[0][0]
# __________________________________________________________________________________________________
# activation_338 (Activation)     (None, None, None, 1 0           batch_normalization_338[0][0]
# __________________________________________________________________________________________________
# activation_341 (Activation)     (None, None, None, 1 0           batch_normalization_341[0][0]
# __________________________________________________________________________________________________
# activation_346 (Activation)     (None, None, None, 1 0           batch_normalization_346[0][0]
# __________________________________________________________________________________________________
# activation_347 (Activation)     (None, None, None, 1 0           batch_normalization_347[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_338[0][0]
#                                                                  activation_341[0][0]
#                                                                  activation_346[0][0]
#                                                                  activation_347[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_352 (BatchN (None, None, None, 1 480         conv2d_352[0][0]
# __________________________________________________________________________________________________
# activation_352 (Activation)     (None, None, None, 1 0           batch_normalization_352[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, None, None, 1 179200      activation_352[0][0]
# __________________________________________________________________________________________________
# batch_normalization_353 (BatchN (None, None, None, 1 480         conv2d_353[0][0]
# __________________________________________________________________________________________________
# activation_353 (Activation)     (None, None, None, 1 0           batch_normalization_353[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, None, None, 1 179200      activation_353[0][0]
# __________________________________________________________________________________________________
# batch_normalization_349 (BatchN (None, None, None, 1 480         conv2d_349[0][0]
# __________________________________________________________________________________________________
# batch_normalization_354 (BatchN (None, None, None, 1 480         conv2d_354[0][0]
# __________________________________________________________________________________________________
# activation_349 (Activation)     (None, None, None, 1 0           batch_normalization_349[0][0]
# __________________________________________________________________________________________________
# activation_354 (Activation)     (None, None, None, 1 0           batch_normalization_354[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, None, None, 1 179200      activation_349[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, None, None, 1 179200      activation_354[0][0]
# __________________________________________________________________________________________________
# batch_normalization_350 (BatchN (None, None, None, 1 480         conv2d_350[0][0]
# __________________________________________________________________________________________________
# batch_normalization_355 (BatchN (None, None, None, 1 480         conv2d_355[0][0]
# __________________________________________________________________________________________________
# activation_350 (Activation)     (None, None, None, 1 0           batch_normalization_350[0][0]
# __________________________________________________________________________________________________
# activation_355 (Activation)     (None, None, None, 1 0           batch_normalization_355[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, None, None, 1 215040      activation_350[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, None, None, 1 215040      activation_355[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_348 (BatchN (None, None, None, 1 576         conv2d_348[0][0]
# __________________________________________________________________________________________________
# batch_normalization_351 (BatchN (None, None, None, 1 576         conv2d_351[0][0]
# __________________________________________________________________________________________________
# batch_normalization_356 (BatchN (None, None, None, 1 576         conv2d_356[0][0]
# __________________________________________________________________________________________________
# batch_normalization_357 (BatchN (None, None, None, 1 576         conv2d_357[0][0]
# __________________________________________________________________________________________________
# activation_348 (Activation)     (None, None, None, 1 0           batch_normalization_348[0][0]
# __________________________________________________________________________________________________
# activation_351 (Activation)     (None, None, None, 1 0           batch_normalization_351[0][0]
# __________________________________________________________________________________________________
# activation_356 (Activation)     (None, None, None, 1 0           batch_normalization_356[0][0]
# __________________________________________________________________________________________________
# activation_357 (Activation)     (None, None, None, 1 0           batch_normalization_357[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_348[0][0]
#                                                                  activation_351[0][0]
#                                                                  activation_356[0][0]
#                                                                  activation_357[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_362 (BatchN (None, None, None, 1 576         conv2d_362[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, None, None, 1 0           batch_normalization_362[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, None, None, 1 258048      activation_362[0][0]
# __________________________________________________________________________________________________
# batch_normalization_363 (BatchN (None, None, None, 1 576         conv2d_363[0][0]
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, None, None, 1 0           batch_normalization_363[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, None, None, 1 258048      activation_363[0][0]
# __________________________________________________________________________________________________
# batch_normalization_359 (BatchN (None, None, None, 1 576         conv2d_359[0][0]
# __________________________________________________________________________________________________
# batch_normalization_364 (BatchN (None, None, None, 1 576         conv2d_364[0][0]
# __________________________________________________________________________________________________
# activation_359 (Activation)     (None, None, None, 1 0           batch_normalization_359[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, None, None, 1 0           batch_normalization_364[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, None, None, 1 258048      activation_359[0][0]
# __________________________________________________________________________________________________
# conv2d_365 (Conv2D)             (None, None, None, 1 258048      activation_364[0][0]
# __________________________________________________________________________________________________
# batch_normalization_360 (BatchN (None, None, None, 1 576         conv2d_360[0][0]
# __________________________________________________________________________________________________
# batch_normalization_365 (BatchN (None, None, None, 1 576         conv2d_365[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, None, None, 1 0           batch_normalization_360[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, None, None, 1 0           batch_normalization_365[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17 (AveragePo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, None, None, 1 258048      activation_360[0][0]
# __________________________________________________________________________________________________
# conv2d_366 (Conv2D)             (None, None, None, 1 258048      activation_365[0][0]
# __________________________________________________________________________________________________
# conv2d_367 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_358 (BatchN (None, None, None, 1 576         conv2d_358[0][0]
# __________________________________________________________________________________________________
# batch_normalization_361 (BatchN (None, None, None, 1 576         conv2d_361[0][0]
# __________________________________________________________________________________________________
# batch_normalization_366 (BatchN (None, None, None, 1 576         conv2d_366[0][0]
# __________________________________________________________________________________________________
# batch_normalization_367 (BatchN (None, None, None, 1 576         conv2d_367[0][0]
# __________________________________________________________________________________________________
# activation_358 (Activation)     (None, None, None, 1 0           batch_normalization_358[0][0]
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, None, None, 1 0           batch_normalization_361[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, None, None, 1 0           batch_normalization_366[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, None, None, 1 0           batch_normalization_367[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_358[0][0]
#                                                                  activation_361[0][0]
#                                                                  activation_366[0][0]
#                                                                  activation_367[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, None, None, 1 0           batch_normalization_368[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, None, None, 1 0           batch_normalization_372[0][0]
# __________________________________________________________________________________________________
# conv2d_369 (Conv2D)             (None, None, None, 3 552960      activation_368[0][0]
# __________________________________________________________________________________________________
# conv2d_373 (Conv2D)             (None, None, None, 1 331776      activation_372[0][0]
# __________________________________________________________________________________________________
# batch_normalization_369 (BatchN (None, None, None, 3 960         conv2d_369[0][0]
# __________________________________________________________________________________________________
# batch_normalization_373 (BatchN (None, None, None, 1 576         conv2d_373[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, None, None, 3 0           batch_normalization_369[0][0]
# __________________________________________________________________________________________________
# activation_373 (Activation)     (None, None, None, 1 0           batch_normalization_373[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_369[0][0]
#                                                                  activation_373[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_378 (BatchN (None, None, None, 4 1344        conv2d_378[0][0]
# __________________________________________________________________________________________________
# activation_378 (Activation)     (None, None, None, 4 0           batch_normalization_378[0][0]
# __________________________________________________________________________________________________
# conv2d_375 (Conv2D)             (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_379 (Conv2D)             (None, None, None, 3 1548288     activation_378[0][0]
# __________________________________________________________________________________________________
# batch_normalization_375 (BatchN (None, None, None, 3 1152        conv2d_375[0][0]
# __________________________________________________________________________________________________
# batch_normalization_379 (BatchN (None, None, None, 3 1152        conv2d_379[0][0]
# __________________________________________________________________________________________________
# activation_375 (Activation)     (None, None, None, 3 0           batch_normalization_375[0][0]
# __________________________________________________________________________________________________
# activation_379 (Activation)     (None, None, None, 3 0           batch_normalization_379[0][0]
# __________________________________________________________________________________________________
# conv2d_376 (Conv2D)             (None, None, None, 3 442368      activation_375[0][0]
# __________________________________________________________________________________________________
# conv2d_377 (Conv2D)             (None, None, None, 3 442368      activation_375[0][0]
# __________________________________________________________________________________________________
# conv2d_380 (Conv2D)             (None, None, None, 3 442368      activation_379[0][0]
# __________________________________________________________________________________________________
# conv2d_381 (Conv2D)             (None, None, None, 3 442368      activation_379[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18 (AveragePo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_374 (Conv2D)             (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_376 (BatchN (None, None, None, 3 1152        conv2d_376[0][0]
# __________________________________________________________________________________________________
# batch_normalization_377 (BatchN (None, None, None, 3 1152        conv2d_377[0][0]
# __________________________________________________________________________________________________
# batch_normalization_380 (BatchN (None, None, None, 3 1152        conv2d_380[0][0]
# __________________________________________________________________________________________________
# batch_normalization_381 (BatchN (None, None, None, 3 1152        conv2d_381[0][0]
# __________________________________________________________________________________________________
# conv2d_382 (Conv2D)             (None, None, None, 1 245760      average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_374 (BatchN (None, None, None, 3 960         conv2d_374[0][0]
# __________________________________________________________________________________________________
# activation_376 (Activation)     (None, None, None, 3 0           batch_normalization_376[0][0]
# __________________________________________________________________________________________________
# activation_377 (Activation)     (None, None, None, 3 0           batch_normalization_377[0][0]
# __________________________________________________________________________________________________
# activation_380 (Activation)     (None, None, None, 3 0           batch_normalization_380[0][0]
# __________________________________________________________________________________________________
# activation_381 (Activation)     (None, None, None, 3 0           batch_normalization_381[0][0]
# __________________________________________________________________________________________________
# batch_normalization_382 (BatchN (None, None, None, 1 576         conv2d_382[0][0]
# __________________________________________________________________________________________________
# activation_374 (Activation)     (None, None, None, 3 0           batch_normalization_374[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_376[0][0]
#                                                                  activation_377[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 7 0           activation_380[0][0]
#                                                                  activation_381[0][0]
# __________________________________________________________________________________________________
# activation_382 (Activation)     (None, None, None, 1 0           batch_normalization_382[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_374[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  activation_382[0][0]
# __________________________________________________________________________________________________
# conv2d_387 (Conv2D)             (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_387 (BatchN (None, None, None, 4 1344        conv2d_387[0][0]
# __________________________________________________________________________________________________
# activation_387 (Activation)     (None, None, None, 4 0           batch_normalization_387[0][0]
# __________________________________________________________________________________________________
# conv2d_384 (Conv2D)             (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_388 (Conv2D)             (None, None, None, 3 1548288     activation_387[0][0]
# __________________________________________________________________________________________________
# batch_normalization_384 (BatchN (None, None, None, 3 1152        conv2d_384[0][0]
# __________________________________________________________________________________________________
# batch_normalization_388 (BatchN (None, None, None, 3 1152        conv2d_388[0][0]
# __________________________________________________________________________________________________
# activation_384 (Activation)     (None, None, None, 3 0           batch_normalization_384[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, None, None, 3 0           batch_normalization_388[0][0]
# __________________________________________________________________________________________________
# conv2d_385 (Conv2D)             (None, None, None, 3 442368      activation_384[0][0]
# __________________________________________________________________________________________________
# conv2d_386 (Conv2D)             (None, None, None, 3 442368      activation_384[0][0]
# __________________________________________________________________________________________________
# conv2d_389 (Conv2D)             (None, None, None, 3 442368      activation_388[0][0]
# __________________________________________________________________________________________________
# conv2d_390 (Conv2D)             (None, None, None, 3 442368      activation_388[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_19 (AveragePo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_383 (Conv2D)             (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_385 (BatchN (None, None, None, 3 1152        conv2d_385[0][0]
# __________________________________________________________________________________________________
# batch_normalization_386 (BatchN (None, None, None, 3 1152        conv2d_386[0][0]
# __________________________________________________________________________________________________
# batch_normalization_389 (BatchN (None, None, None, 3 1152        conv2d_389[0][0]
# __________________________________________________________________________________________________
# batch_normalization_390 (BatchN (None, None, None, 3 1152        conv2d_390[0][0]
# __________________________________________________________________________________________________
# conv2d_391 (Conv2D)             (None, None, None, 1 393216      average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_383 (BatchN (None, None, None, 3 960         conv2d_383[0][0]
# __________________________________________________________________________________________________
# activation_385 (Activation)     (None, None, None, 3 0           batch_normalization_385[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, None, None, 3 0           batch_normalization_386[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, None, None, 3 0           batch_normalization_389[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, None, None, 3 0           batch_normalization_390[0][0]
# __________________________________________________________________________________________________
# batch_normalization_391 (BatchN (None, None, None, 1 576         conv2d_391[0][0]
# __________________________________________________________________________________________________
# activation_383 (Activation)     (None, None, None, 3 0           batch_normalization_383[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_385[0][0]
#                                                                  activation_386[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 7 0           activation_389[0][0]
#                                                                  activation_390[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, None, None, 1 0           batch_normalization_391[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_383[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_4[0][0]
#                                                                  activation_391[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'mixed0'
# Name of layers used for style loss
style_layers = ['mixed1']
# Weights in the weighted average of the loss components
total_variation_weight = 0
style_weight = 100
content_weight = 0

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)

# %%
# Get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

# Function to fetch the values of the current loss and the current gradients
fetch_loss_and_grads = K.function([combination_image], [loss, grads])


class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        x = x.reshape((1, img_height, img_width, 3))
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1].flatten().astype('float64')
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import time

result_prefix = 'style_transfer_result_resnet50_try3'
iterations = 10

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=10)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1.48901
# Image saved as style_transfer_result_resnet50_try3_at_iteration_0.png
# Iteration 0 completed in 27s
# Start of iteration 1
# Current loss value: 0.630519
# Image saved as style_transfer_result_resnet50_try3_at_iteration_1.png
# Iteration 1 completed in 20s
# Start of iteration 2
# Current loss value: 0.35766
# Image saved as style_transfer_result_resnet50_try3_at_iteration_2.png
# Iteration 2 completed in 20s
# Start of iteration 3
# Current loss value: 0.236859
# Image saved as style_transfer_result_resnet50_try3_at_iteration_3.png
# Iteration 3 completed in 20s
# Start of iteration 4
# Current loss value: 0.176448
# Image saved as style_transfer_result_resnet50_try3_at_iteration_4.png
# Iteration 4 completed in 20s
# Start of iteration 5
# Current loss value: 0.140275
# Image saved as style_transfer_result_resnet50_try3_at_iteration_5.png
# Iteration 5 completed in 20s
# Start of iteration 6
# Current loss value: 0.122493
# Image saved as style_transfer_result_resnet50_try3_at_iteration_6.png
# Iteration 6 completed in 20s
# Start of iteration 7
# Current loss value: 0.110266
# Image saved as style_transfer_result_resnet50_try3_at_iteration_7.png
# Iteration 7 completed in 20s
# Start of iteration 8
# Current loss value: 0.101609
# Image saved as style_transfer_result_resnet50_try3_at_iteration_8.png
# Iteration 8 completed in 20s
# Start of iteration 9
# Current loss value: 0.0950989
# Image saved as style_transfer_result_resnet50_try3_at_iteration_9.png
# Iteration 9 completed in 20s

# %%
from matplotlib import pyplot as plt

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()

# %%
# Dict mapping layer names to activation tensors
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Name of layer used for content loss
content_layer = 'res5b_branch2a'
# Name of layers used for style loss
style_layers = ['conv1',
                'res2a_branch2a',
               'res5a_branch2a']
# Weights in the weighted average of the loss components
total_variation_weight = 1e-4
style_weight = 1.
content_weight = 0.025

# Define the loss by adding all components to a `loss` variable
loss = K.variable(0.)
layer_features = outputs_dict[content_layer]
target_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss += content_weight * content_loss(target_image_features,
                                      combination_features)
for layer_name in style_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss += (style_weight / len(style_layers)) * sl
loss += total_variation_weight * total_variation_loss(combination_image)

# %%
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
import time

result_prefix = 'style_transfer_result_resnet50_try2'
iterations = 10

# Run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss.
# This is our initial state: the target image.
# Note that `scipy.optimize.fmin_l_bfgs_b` can only process flat vectors.
x = preprocess_image(target_image_path)
x = x.flatten()
for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x,
                                     fprime=evaluator.grads, maxfun=10)
    print('Current loss value:', min_val)
    # Save current generated image
    img = x.copy().reshape((img_height, img_width, 3))
    img = deprocess_image(img)
    fname = result_prefix + '_at_iteration_%d.png' % i
    imsave(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 6.85911e+06
# Image saved as style_transfer_result_resnet50_try2_at_iteration_0.png
# Iteration 0 completed in 52s
# Start of iteration 1
# Current loss value: 720073.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_1.png
# Iteration 1 completed in 50s
# Start of iteration 2
# Current loss value: 424753.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_2.png
# Iteration 2 completed in 50s
# Start of iteration 3
# Current loss value: 367765.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_3.png
# Iteration 3 completed in 51s
# Start of iteration 4
# Current loss value: 340554.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_4.png
# Iteration 4 completed in 51s
# Start of iteration 5
# Current loss value: 321440.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_5.png
# Iteration 5 completed in 51s
# Start of iteration 6
# Current loss value: 304730.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_6.png
# Iteration 6 completed in 51s
# Start of iteration 7
# Current loss value: 292909.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_7.png
# Iteration 7 completed in 51s
# Start of iteration 8
# Current loss value: 269172.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_8.png
# Iteration 8 completed in 51s
# Start of iteration 9
# Current loss value: 260524.0
# Image saved as style_transfer_result_resnet50_try2_at_iteration_9.png
# Iteration 9 completed in 51s

# %%
from matplotlib import pyplot as plt

# Content image
plt.imshow(load_img(target_image_path, target_size=(img_height, img_width)))
plt.figure()

# Style image
plt.imshow(load_img(style_reference_image_path, target_size=(img_height, img_width)))
plt.figure()

# Generate image
plt.imshow(img)
plt.show()
